# %%
# %run twisted_graphene.py

# %%
d_inter=3.36

# %%
g11=TwistedBilayerGraphene(1,1,sparse=True)
g11.calc_hops(d_inter)
g11.set_kpath(g11.path_KGMKp,[20,20,20])
g11.set_hamiltonian(0.0,0.0)
g11.calc_bands(4,0.0)
g11.bands0=g11.bands
g11.set_hamiltonian(1.0,0.0)
g11.calc_bands(4,0.0)
g11.bands1=g11.bands
# Out:
# /home/vgmdu/MEGA/Física/Twistrônica/code/twisted_graphene.py:208: RuntimeWarning: invalid value encountered in true_divide
#   xx=np.nan_to_num(x/r) #cosseno direcional na direção x
# /home/vgmdu/MEGA/Física/Twistrônica/code/twisted_graphene.py:209: RuntimeWarning: invalid value encountered in true_divide
#   yy=np.nan_to_num(y/r) #cosseno direcional na direção y

# %%
g51=TwistedBilayerGraphene(5,1,sparse=True)
g51.calc_hops(d_inter)
g51.set_kpath(g51.path_KGMKp,[10,10,10])
g51.set_hamiltonian(0.0,0.0)
g51.calc_bands(4,0.0)
g51.bands0=g51.bands
g51.set_hamiltonian(1.0,0.0)
g51.calc_bands(4,0.0)
g51.bands1=g51.bands

# %%
g101=TwistedBilayerGraphene(10,1)
g101.calc_hops(d_inter)
g101.set_kpath(g101.path_KGMKp,[10,10,10])
g101.set_hamiltonian(0.0,0.0)
g101.calc_bands(4,0.0)
g101.bands0=g101.bands
g101.set_hamiltonian(1.0,0.0)
g101.calc_bands(4,0.0)
g101.bands1=g101.bands

# %%
g=TwistedBilayerGraphene(20,1)
g.calc_hops(d_inter)
g.set_kpath(g.path_KGMKp,[10,10,10])
g.set_hamiltonian(0.0,0.0)
g.calc_bands(4,0.0)
g.bands0=g.bands
g.set_hamiltonian(1.0,0.0)
g.calc_bands(4,0.0)
g.bands1=g.bands
g201=g

# %%
g=TwistedBilayerGraphene(30,1) #magic angle
g.calc_hops(d_inter)
g.set_kpath(g.path_KGMKp,[10,10,10])
g.set_hamiltonian(0.0,0.0)
g.calc_bands(4,0.0)
g.bands0=g.bands
g.set_hamiltonian(1.0,0.0)
g.calc_bands(4,0.0)
g.bands1=g.bands
g301=g

# %%
g=TwistedBilayerGraphene(30,1) #magic angle, with more bands
g.calc_hops(d_inter)
g.set_kpath(g.path_KGMKp,[50,50,10])
g.set_hamiltonian(0.0,0.0)
g.calc_bands(12,0.0)
g.bands0=g.bands
g.set_hamiltonian(1.0,0.0)
g.calc_bands(12,0.0)
g.bands1=g.bands
g301_12=g

# %%
height=4.20
ratio=2.0

plt.figure(figsize=(ratio*height,height))
plt.subplots_adjust(hspace=0.1,wspace=0.35)

plt.subplot(231)

g=g11
plt.plot(g.ell,g.bands0,'gx',ms=3)
plt.plot(g.ell,g.bands1,'b.',ms=3)
plt.title(f'{g.theta*180/np.pi:.2f}°',loc="left",x=0.06,y=0.75)
plt.xticks(g.ell[g.kticks],['','','',''])
plt.grid(True)
plt.ylabel('Energy [eV]')
# plt.legend(['off']+3*['__nolegend__']+['on'],title='interlayer coupling')
plt.ylim((-4.5,4.5))
plt.xlim((g.ell[0],g.ell[-1]))

plt.subplot(232)

g=g51
plt.plot(g.ell,g.bands0,'gx',ms=3)
plt.plot(g.ell,g.bands1,'b.',ms=3)
plt.title(f'{g.theta*180/np.pi:.2f}°',loc="left",x=0.1,y=0.75)
plt.xticks(g.ell[g.kticks],['','','',''])
plt.grid(True)
# plt.ylabel('Energy [eV]')
# plt.legend(['off']+3*['__nolegend__']+['on'],title='interlayer coupling')
plt.ylim((-4.5,4.5))
plt.xlim((g.ell[0],g.ell[-1]))

plt.subplot(233)

g=g101
plt.plot(g.ell,g.bands0,'gx',ms=3)
plt.plot(g.ell,g.bands1,'b.',ms=3)
plt.title(f'{g.theta*180/np.pi:.2f}°',loc="left",x=0.1,y=0.75)
plt.xticks(g.ell[g.kticks],['','','',''])
plt.grid(True)
# plt.ylabel('Energy [eV]')
# plt.legend(['off']+3*['__nolegend__']+['on'],title='interlayer coupling')
plt.ylim((-4.5,4.5))
plt.xlim((g.ell[0],g.ell[-1]))

plt.subplot(234)

g=g201
plt.plot(g.ell,g.bands0,'gx',ms=3)
plt.plot(g.ell,g.bands1,'b.',ms=3)
plt.title(f'{g.theta*180/np.pi:.2f}°',loc="left",x=0.1,y=0.75)
plt.xticks(g.ell[g.kticks],['$\mathbf{K}$','$\mathbf{\Gamma}$','$\mathbf{M}$',"$\mathbf{K}'$"])
plt.grid(True)
plt.ylabel('Energy [eV]')
# plt.legend(['off']+3*['__nolegend__']+['on'],title='interlayer coupling')
plt.ylim((-4.5,4.5))
plt.xlim((g.ell[0],g.ell[-1]))

plt.subplot(235)

g=g301
plt.plot(g.ell,g.bands0,'gx',ms=3)
plt.plot(g.ell,g.bands1,'b.',ms=3)
plt.title(f'{g.theta*180/np.pi:.2f}°',loc="left",x=0.1,y=0.75)
plt.xticks(g.ell[g.kticks],['$\mathbf{K}$','$\mathbf{\Gamma}$','$\mathbf{M}$',"$\mathbf{K}'$"])
plt.grid(True)
# plt.ylabel('Energy [eV]')
# plt.legend(['off']+3*['__nolegend__']+['on'],title='interlayer coupling')
plt.ylim((-4.5,4.5))
plt.xlim((g.ell[0],g.ell[-1]))

plt.subplot(236)

g=g301_12
plt.plot(g.ell,g.bands0,'gx',ms=3)
plt.plot(g.ell,g.bands1,'b.',ms=3)
# plt.plot(g.ell[g.kticks[1]],g.bands1[g.kticks[1],6],'ro')
# plt.plot(g.ell[g.kticks[1]],g.bands1[g.kticks[1],5],'ro')
plt.title(f'{g.theta*180/np.pi:.2f}°',loc="left",x=0.15,y=0.68)
plt.xticks(g.ell[g.kticks],['$\mathbf{K}$','$\mathbf{\Gamma}$','$\mathbf{M}$',"$\mathbf{K}'$"])
plt.grid(True)
# plt.ylabel('Energy [eV]')
# plt.legend(['off']+3*['__nolegend__']+['on'],title='interlayer coupling')
plt.ylim((-0.06,0.06))
plt.xlim((g.ell[0],g.ell[-1]))

# plt.savefig('Fig18_band_flattening.svg')

plt.show()
