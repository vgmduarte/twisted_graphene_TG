# %%
import numpy as np

# %%
a=np.array([[1,2,0],[4,5,0],[0,0,1]])
a
# Out:
# array([[1, 2, 0],
#        [4, 5, 0],
#        [0, 0, 1]])

# %%
np.linalg.inv(a)
# Out:
# array([[-1.66666667,  0.66666667,  0.        ],
#        [ 1.33333333, -0.33333333,  0.        ],
#        [ 0.        ,  0.        ,  1.        ]])

# %%
5/-3
# Out:
# -1.6666666666666667

# %%
1/-3
# Out:
# -0.3333333333333333

# %%
-2/-3
# Out:
# 0.6666666666666666

# %%
-4/-3
# Out:
# 1.3333333333333333
